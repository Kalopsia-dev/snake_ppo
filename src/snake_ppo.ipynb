# %% [markdown]
# ## Proximal Policy Optimisation in Snake
#
# <center><img src="../assets/snake.png"/></center>

# %% [markdown]
# ### 1. Environment
# The environment is a fully vectorised Snake game implemented in NumPy, with an optional GUI reliant on Pygame. The game area is represented as a 2-dimensional integer array. Blank positions have a value of 0, the food position is marked with -1, and the snake is represented as a sequence of ascending integers, starting at 2. Moving the snake is achieved by adding 1 to each of its segments and inserting the head's index at its next position.

# %%
from game import Snake

# Launch a playable instance of Snake. Use the arrow keys to control the snake.
Snake.play(width = 12, height = 9, fps = 3)

# %% [markdown]
# #### 1.1 Action Space
# While there are technically four possible movement directions ("Left," "Right," "Up," "Down"), the game will be played from the snake's perspective. This results in an action space of three discrete elements: "Turn Left," "Move Forward," and "Turn Right", which reduces the number of learnable parameters and prevents collisions with the snake's second segment.
#
# Both actions and directions are represented as enums of integers, with values defined deliberately to allow arithmetic operations to determine the result of a direction-action pair, eliminating the need for manual mapping. Directions and actions are defined in clockwise order with ascending indices (0 through 3 and 0 through 2, respectively). The next direction after performing an action is computed as the sum of the current direction's index and the action's index (minus 1), followed by modulo division.
#
# #### 1.2 Observation Space
# Conventionally, Snake involves a top-down view of a fully observable game area. To reduce the number of learnable parameters compared to a convolutional neural network and to improve convergence speed, a different approach was chosen. Instead of providing a tensor representation of the entire game state, the game is played from the snake's perspective, rendering the game area only partially observable. The agent operates within a low-dimensional observation space containing the following components:
# - 5 decimal values representing danger in the left, left-forward, forward, right-forward, and right directions, with values ranging from 0 to 2.
# - A 4-dimensional one-hot vector of the snake's current movement direction.
# - A 4-dimensional one-hot vector of the food's relative position.
# - The percentage of used-up game time, introducing a sense of urgency similar to a penalty per game step.
#
# The snake perceives danger as follows:
# 1. Generate a matrix where 1s represent positions that would harm the snake by the time it reaches them. Since the snake cannot leave the game area, this "danger map" extends slightly beyond the game state and is framed by danger values.
# 2. Create an integer array containing the Manhattan (L1) distance between the snake's head and each position on the danger map.
# 3. Normalise the danger map by dividing it by the squared L1 distance (with a lower bound of 1 to avoid dividing by zero).
# 4. Compute the perceived danger in each direction as the sum of normalised danger map values in that direction (excluding the head).
#
# <center><img src="../assets/danger_map.png"/></center>
#
# This representation offers the added advantage of being entirely independent of the game's grid size. A trained agent that performs well on a 12x9 grid will achieve similar performance on smaller or larger grids, as neither the observation dimensions nor the value ranges change. One-hot values have a fixed value spectrum, and danger observations, as implemented, form a geometric series converging to a maximum of 2.
#
# #### 1.3 Rewards
# Suitable rewards are crucial for successful reinforcement learning, as they substantially impact both convergence speed and the agent's strategy after training. The following rewards are used:
# - **+1**: The snake eats food.
# - **-2**: The snake collides with itself or runs out of time (i.e., exceeds a number of moves dependent on its current length and the game's grid size).
# - A small penalty per game step.

# %% [markdown]
# ### 2. Model Definition
# The model to be trained is an actor-critic policy network comprising the following components:
# - **Shared linear layers:** Transform the input observation into a shared feature vector.
# - **Value stream:** Predicts the value of the observation using the shared features.
# - **Policy stream:** Predicts logarithmic action probabilities based on the shared features.

# %% [markdown]
# ### 3. Training Algorithm
# Training will be done using OpenAI's Proximal Policy Optimisation (PPO) algorithm, a policy-gradient method renowned for its robustness and ease of implementation.

# %% [markdown]
# #### 3.1 Advantage Estimation
# To stabilise training and improve convergence speed, we estimate the agent's average performance in a given state, referred to as the state's advantage. This metric provides a more accurate evaluation of the quality of actions.
# A popular method for calculating advantages is **Generalised Advantage Estimation (GAE)**, defined as:
# $$
# A^{\text{GAE}}_t = \sum_{l=0}^\infty (\gamma \lambda)^l \delta_{t+l}
# $$
# where the reward deltas are computed as:
# $$
# \delta_t = r_t + \gamma V(s_{t+1}) - V(s_t)
# $$
#
# #### 3.2 Training Data
# Each training step simulates an entire game, tracking the following features:
# - **Observed game states:** The states encountered during gameplay.
# - **Sampled actions:** Actions drawn from the model's policy logits, as predicted by the policy stream.
# - **Rewards:** The rewards received for taking the above actions.
# - **Action probabilities:** The log probabilities of each action, as predicted by the policy stream.
# - **Predicted state values:** The state values predicted by the model, adjusted using the Generalised Advantage Estimate (GAE).
#
# Typically, a training function would require an iteration limit. However, the Snake environment enforces its own iteration limit, making this step redundant.
#
# #### 3.3 Training Objectives
# PPO separates the optimisation of the policy and value functions, each with a distinct training objective (and corresponding optimizer):
#
# ##### 3.3.1 Value Loss
# The value function loss measures the mean squared error between the predicted state values under the current policy and the actual return values:
# $$
# L^{\text{value}}(\theta) = \mathbb{E}_t \left[ \left( V_\theta(s_t) - G_t \right)^2 \right]
# $$
#
# ##### 3.3.2 Policy Loss
# The policy loss ensures stable updates by limiting large changes to the policy. This is achieved through the **Clipped Surrogate Objective**:
# $$
# L^{\text{clip}}(\theta) = \mathbb{E}_t \left[ \min \left( r_t(\theta) A_t, \text{clip}(r_t(\theta), 1 - \epsilon, 1 + \epsilon) A_t \right) \right]
# $$
#
# Here, the probability ratio between the new and old policies is defined as:
# $$
# r_t(\theta) = \frac{\pi_\theta(a_t \mid s_t)}{\pi_{\theta_{\text{old}}}(a_t \mid s_t)}
# $$
#
# ##### 3.3.3 Clipping Mechanism
# PPO's clipping mechanism restricts policy updates to a trusted range, enabling multiple gradient steps on the same data. For each game, up to `max_policy_updates` policy updates are performed. The training episode ends if the **Kullback–Leibler (KL) divergence** between the old and new action distributions exceeds a predefined threshold. The KL divergence is defined as:
# $$
# D_{\text{KL}}(P \| Q) = \sum_x P(x) \log \frac{P(x)}{Q(x)}
# $$

# %% [markdown]
# ### 4. Training Loop
# The model is trained using the following process:
# 1. The agent plays the game until it reaches a terminal state.
# 2. Training data is collected, and the Generalised Advantage Estimate (GAE) is computed.
# 3. The data is randomly shuffled to enhance training stability.
# 4. Separate gradient steps are performed for the policy and value networks.
#
# During training, the agent's high score is monitored. If it surpasses the previous best, a checkpoint of the agent is saved. After the final game, a final checkpoint is created, concluding the process.

# %%
from agent.training import PPOTrainer # The trainer class contains all optimization logic for the PPO algorithm.
from agent.training import train      # The training function runs the training loop for a given environment and trainer.
from agent import ACN                 # The model is an actor-critic network that predicts action probabilities and state values.
from game.env import SnakeEnv         # The environment class wraps a vectorised game instance, computing observations and rewards.
from game.gui import render_replay    # The render function creates a gif of a game replay.

# Create a new game instance and agent model.
env = SnakeEnv(
    width  = 5,
    height = 5,
    gui    = False,
)
model = ACN(
    observation_space = env.observation_space,
    action_space      = env.action_space,
    hidden_size       = 128,
)
trainer = PPOTrainer(
    model              = model,
    ppo_clip_value     = 0.2,  # PPO clip value. Clamps the ratio of old and new policy to prevent large updates.
    max_policy_updates = 30,   # Maximum number of policy updates per game. Prevents overfitting.
    target_kl_div      = 0.02, # Maximum allowed KL divergence. Specifies the safe range for policy updates.
    policy_lr          = 2e-5, # Learning rate for the policy network. Higher values can skip local minima, but may overshoot.
    value_lr           = 2e-6, # Learning rate for the value network. Lower than the policy rate to reduce feature layer drift.
    gamma              = 0.99, # Discount factor. Determines the importance of future rewards.
)

# Train the agent.
best_game = train(
    env            = env,
    trainer        = trainer,
    episodes       = 100_000,
    checkpoint_dir = '../assets/models/',
)
# Finally, render a gif of the best game.
render_replay(best_game, output_file = '../assets/gameplay.gif')
# Out:
# EPISODE    100 | Mean:  0.1, Highscore:  1 |▕█▏
# EPISODE    200 | Mean:  0.3, Highscore:  2 |▕█ ▏
# EPISODE    300 | Mean:  0.4, Highscore:  3 |▕█░ ▏
# EPISODE    400 | Mean:  0.2, Highscore:  3 |▕█ ▏
# EPISODE    500 | Mean:  0.6, Highscore:  3 |▕█░ ▏
# EPISODE    600 | Mean:  0.4, Highscore:  3 |▕█░▏
# EPISODE    700 | Mean:  0.5, Highscore:  3 |▕█░▏
# EPISODE    800 | Mean:  0.8, Highscore:  3 |▕░█░▏
# EPISODE    900 | Mean:  0.9, Highscore:  3 |▕░█░▏
# EPISODE   1000 | Mean:  2.3, Highscore:  9 |▕ ░█░     ▏
# EPISODE   1100 | Mean:  4.5, Highscore: 11 |▕   ░█░░    ▏
# EPISODE   1200 | Mean:  8.8, Highscore: 21 |▕      ░░░█░░░        ▏
# EPISODE   1300 | Mean: 16.9, Highscore: 32 |  ▕          ░░░░█░░░░░         ▏
# EPISODE   1400 | Mean: 21.6, Highscore: 35 |▕                 ░░░░░█░░░        ▏
# EPISODE   1500 | Mean: 25.1, Highscore: 39 | ▕                     ░░█░░░░         ▏
# EPISODE   1600 | Mean: 25.3, Highscore: 39 |      ▕                ░░░█░░░        ▏
# EPISODE   1700 | Mean: 26.0, Highscore: 39 |  ▕                     ░░█░░░        ▏
# EPISODE   1800 | Mean: 26.8, Highscore: 39 |       ▕                ░░░█░░        ▏
# EPISODE   1900 | Mean: 26.8, Highscore: 44 |  ▕                      ░░█░░░             ▏
# EPISODE   2000 | Mean: 29.0, Highscore: 48 |         ▕                ░░█░░░                ▏
# EPISODE   2100 | Mean: 27.5, Highscore: 48 |     ▕                   ░░░█░░░            ▏
# EPISODE   2200 | Mean: 27.9, Highscore: 48 | ▕                        ░█░░░░               ▏
# EPISODE   2300 | Mean: 27.0, Highscore: 48 | ▕                       ░░█░░░     ▏
# EPISODE   2400 | Mean: 28.4, Highscore: 48 | ▕                       ░░░░█░░           ▏
# EPISODE   2500 | Mean: 27.2, Highscore: 48 | ▕                       ░░░█░░      ▏
# EPISODE   2600 | Mean: 27.7, Highscore: 48 |     ▕                   ░░░█░░            ▏
# EPISODE   2700 | Mean: 27.1, Highscore: 48 |   ▕                     ░░█░░░          ▏
# EPISODE   2800 | Mean: 27.9, Highscore: 48 |   ▕                     ░░░█░░                ▏
# EPISODE   2900 | Mean: 28.4, Highscore: 48 |                ▕       ░░░░█░░░            ▏
# EPISODE   3000 | Mean: 29.3, Highscore: 48 |   ▕                      ░░░█░░░           ▏
# EPISODE   3100 | Mean: 28.9, Highscore: 48 |       ▕                  ░░█░░░             ▏
# EPISODE   3200 | Mean: 29.7, Highscore: 48 |                      ▕   ░░█░░░░               ▏
# EPISODE   3300 | Mean: 29.8, Highscore: 48 |        ▕                  ░░░█░░             ▏
# EPISODE   3400 | Mean: 29.0, Highscore: 48 |                     ▕    ░░█░░░           ▏
# EPISODE   3500 | Mean: 28.6, Highscore: 48 |     ▕                    ░░░█░░             ▏
# EPISODE   3600 | Mean: 29.6, Highscore: 48 |                      ▕   ░░░█░░░              ▏
# EPISODE   3700 | Mean: 29.8, Highscore: 48 |    ▕                     ░░░░█░░           ▏
# EPISODE   3800 | Mean: 29.4, Highscore: 48 |             ▕            ░░░░█░░         ▏
# EPISODE   3900 | Mean: 30.6, Highscore: 49 |            ▕              ░░░█░░░░              ▏
# EPISODE   4000 | Mean: 29.7, Highscore: 50 |                     ▕    ░░░█░░░                 ▏
# EPISODE   4100 | Mean: 29.5, Highscore: 50 |          ▕               ░░░█░░░░            ▏
# EPISODE   4200 | Mean: 30.7, Highscore: 50 |                    ▕      ░░░█░░░░             ▏
# EPISODE   4300 | Mean: 29.9, Highscore: 55 |                     ▕     ░░█░░░                      ▏
# EPISODE   4400 | Mean: 29.4, Highscore: 55 |             ▕             ░░█░░           ▏
# EPISODE   4500 | Mean: 30.9, Highscore: 55 |                       ▕   ░░░█░░░░          ▏
# EPISODE   4600 | Mean: 29.8, Highscore: 55 |                     ▕     ░░█░░░░         ▏
# EPISODE   4700 | Mean: 30.7, Highscore: 55 |                       ▕   ░░░█░░░         ▏
# EPISODE   4800 | Mean: 30.5, Highscore: 55 |          ▕                 ░░░█░           ▏
# EPISODE   4900 | Mean: 29.8, Highscore: 55 |                ▕         ░░░█░░░░               ▏
# EPISODE   5000 | Mean: 29.9, Highscore: 55 |              ▕            ░░░█░░░     ▏
# EPISODE   5100 | Mean: 30.3, Highscore: 55 |                     ▕     ░░█░░░░                ▏
# EPISODE   5200 | Mean: 29.2, Highscore: 55 |                   ▕      ░░█░░░░░           ▏
# EPISODE   5300 | Mean: 29.9, Highscore: 55 |                     ▕    ░░░█░░░░            ▏
# EPISODE   5400 | Mean: 30.1, Highscore: 55 |                      ▕   ░░░█░░░░         ▏
# EPISODE   5500 | Mean: 30.2, Highscore: 55 |        ▕                  ░░█░░░░                   ▏
# EPISODE   5600 | Mean: 30.0, Highscore: 55 |                     ▕     ░░░█░░░          ▏
# EPISODE   5700 | Mean: 29.6, Highscore: 55 |                  ▕        ░█░░░░░        ▏
# EPISODE   5800 | Mean: 29.9, Highscore: 55 |                      ▕   ░░█░░░░             ▏
# EPISODE   5900 | Mean: 30.5, Highscore: 55 |                     ▕     ░░█░░░░                ▏
# EPISODE   6000 | Mean: 30.1, Highscore: 55 |               ▕          ░░░█░░░░          ▏
# EPISODE   6100 | Mean: 31.1, Highscore: 55 |                     ▕      ░░░█░░░             ▏
# EPISODE   6200 | Mean: 30.1, Highscore: 55 |                  ▕       ░░░░█░░░          ▏
# EPISODE   6300 | Mean: 29.9, Highscore: 55 |       ▕                  ░░░█░░░░         ▏
# EPISODE   6400 | Mean: 31.2, Highscore: 55 |                  ▕        ░░░░█░░░       ▏
# EPISODE   6500 | Mean: 29.9, Highscore: 55 |                ▕         ░░░█░░░░          ▏
# EPISODE   6600 | Mean: 30.3, Highscore: 55 |                   ▕       ░░█░░░░░           ▏
# EPISODE   6700 | Mean: 30.6, Highscore: 55 |                       ▕   ░░░█░░░                 ▏
# EPISODE   6800 | Mean: 29.7, Highscore: 55 |               ▕          ░░░█░░░           ▏
# EPISODE   6900 | Mean: 30.1, Highscore: 55 |                ▕          ░░█░░░░            ▏
# EPISODE   7000 | Mean: 29.6, Highscore: 55 |                  ▕       ░░░█░░░░           ▏
# EPISODE   7100 | Mean: 31.2, Highscore: 55 |                 ▕         ░░░█░░░░            ▏
# EPISODE   7200 | Mean: 30.8, Highscore: 55 |              ▕            ░░░█░░░░             ▏
# EPISODE   7300 | Mean: 30.0, Highscore: 55 |             ▕            ░░░░█░░░           ▏
# EPISODE   7400 | Mean: 29.6, Highscore: 55 |              ▕           ░░░█░░░              ▏
# EPISODE   7500 | Mean: 31.6, Highscore: 55 |                      ▕    ░░░█░░░░░               ▏
# EPISODE   7600 | Mean: 29.4, Highscore: 55 |             ▕            ░░░█░░░                  ▏
# EPISODE   7700 | Mean: 30.1, Highscore: 55 |                     ▕    ░░░█░░░░               ▏
# EPISODE   7800 | Mean: 30.9, Highscore: 55 |                      ▕    ░░░█░░░░              ▏
# EPISODE   7900 | Mean: 30.6, Highscore: 55 |                   ▕       ░░░█░░░░                  ▏
# EPISODE   8000 | Mean: 31.1, Highscore: 55 |               ▕           ░░░░█░░░              ▏
# EPISODE   8100 | Mean: 31.5, Highscore: 55 |                     ▕     ░░░█░░░░░          ▏
# EPISODE   8200 | Mean: 31.0, Highscore: 55 |                     ▕     ░░░░█░░░            ▏
# EPISODE   8300 | Mean: 29.7, Highscore: 55 |                       ▕   ░░█░░░           ▏
# EPISODE   8400 | Mean: 29.8, Highscore: 55 |                    ▕      ░░█░░░          ▏
# EPISODE   8500 | Mean: 30.9, Highscore: 55 |           ▕               ░░░█░░░░░          ▏
# EPISODE   8600 | Mean: 30.2, Highscore: 55 |         ▕                 ░░░█░░░       ▏
# EPISODE   8700 | Mean: 31.2, Highscore: 55 |               ▕            ░░█░░░░            ▏
# EPISODE   8800 | Mean: 30.5, Highscore: 55 |                     ▕     ░░█░░░░░             ▏
# EPISODE   8900 | Mean: 31.0, Highscore: 55 |                   ▕        ░░█░░░            ▏
# EPISODE   9000 | Mean: 31.2, Highscore: 55 |                       ▕   ░░░░█░░░            ▏
# EPISODE   9100 | Mean: 30.3, Highscore: 55 |                     ▕     ░░░█░░░         ▏
# EPISODE   9200 | Mean: 30.8, Highscore: 55 |             ▕             ░░░█░░░░               ▏
# EPISODE   9300 | Mean: 31.0, Highscore: 55 |                      ▕    ░░█░░░░░          ▏
# EPISODE   9400 | Mean: 31.5, Highscore: 55 |                      ▕    ░░░█░░░░░                   ▏
# EPISODE   9500 | Mean: 31.3, Highscore: 62 |                      ▕    ░░░█░░░░                           ▏
# EPISODE   9600 | Mean: 30.0, Highscore: 62 |            ▕             ░░░█░░░░░              ▏
# EPISODE   9700 | Mean: 31.1, Highscore: 62 |                       ▕   ░░░█░░░                        ▏
# EPISODE   9800 | Mean: 29.5, Highscore: 62 |                     ▕     ░░█░░           ▏
# EPISODE   9900 | Mean: 30.4, Highscore: 62 |                      ▕    ░░█░░░░             ▏
# EPISODE  10000 | Mean: 31.8, Highscore: 62 |                     ▕     ░░░░█░░░░          ▏
# EPISODE  10100 | Mean: 30.5, Highscore: 62 |                      ▕    ░░░█░░░░       ▏
# EPISODE  10200 | Mean: 31.5, Highscore: 62 |                       ▕   ░░░█░░░░░                       ▏
# EPISODE  10300 | Mean: 31.1, Highscore: 62 |                      ▕    ░░█░░░░░░          ▏
# EPISODE  10400 | Mean: 31.4, Highscore: 62 |                     ▕     ░░░░█░░░░            ▏
# EPISODE  10500 | Mean: 31.6, Highscore: 62 |       ▕                   ░░░█░░░░░                 ▏
# EPISODE  10600 | Mean: 31.4, Highscore: 62 |              ▕             ░░░█░░░░            ▏
# EPISODE  10700 | Mean: 32.2, Highscore: 62 |                  ▕         ░░░█░░░░░               ▏
# EPISODE  10800 | Mean: 30.4, Highscore: 62 |             ▕             ░░░█░░░░         ▏
# EPISODE  10900 | Mean: 32.7, Highscore: 62 |           ▕                ░░░░█░░░░                    ▏
# EPISODE  11000 | Mean: 30.6, Highscore: 62 |           ▕               ░░░█░░░░░           ▏
# EPISODE  11100 | Mean: 30.9, Highscore: 62 |          ▕                ░░░█░░░░                   ▏
# EPISODE  11200 | Mean: 31.1, Highscore: 62 |    ▕                     ░░░░░█░░░░             ▏
# EPISODE  11300 | Mean: 31.0, Highscore: 62 |          ▕                 ░░░█░░░         ▏
# EPISODE  11400 | Mean: 31.3, Highscore: 62 | ▕                         ░░░█░░░░░                    ▏
# EPISODE  11500 | Mean: 32.4, Highscore: 62 | ▕                          ░░░░█░░░░░           ▏
# EPISODE  11600 | Mean: 33.0, Highscore: 62 |          ▕                 ░░░░░█░░░░                ▏
# EPISODE  11700 | Mean: 33.2, Highscore: 62 |                   ▕        ░░░░█░░░░░             ▏
# EPISODE  11800 | Mean: 31.5, Highscore: 62 |            ▕               ░░░█░░░░               ▏
# EPISODE  11900 | Mean: 32.0, Highscore: 62 |            ▕               ░░░█░░░░                     ▏
# EPISODE  12000 | Mean: 31.3, Highscore: 62 |         ▕                 ░░░█░░░░░                    ▏
# EPISODE  12100 | Mean: 30.1, Highscore: 62 |          ▕                ░░░█░░░               ▏
# EPISODE  12200 | Mean: 31.6, Highscore: 62 | ▕                         ░░░░█░░░░                 ▏
# EPISODE  12300 | Mean: 32.0, Highscore: 62 |                 ▕          ░░░█░░░░                        ▏
# EPISODE  12400 | Mean: 30.7, Highscore: 65 |               ▕          ░░░░█░░░                               ▏
# EPISODE  12500 | Mean: 31.5, Highscore: 65 |    ▕                       ░░░█░░░░                   ▏
# EPISODE  12600 | Mean: 32.9, Highscore: 65 |       ▕                    ░░░░░█░░░░░                        ▏
# EPISODE  12700 | Mean: 31.7, Highscore: 65 |               ▕           ░░░░█░░░░░                      ▏
# EPISODE  12800 | Mean: 32.6, Highscore: 65 |                ▕           ░░░█░░░░                         ▏
# EPISODE  12900 | Mean: 31.9, Highscore: 65 |   ▕                        ░░░█░░░░                      ▏
# EPISODE  13000 | Mean: 33.2, Highscore: 65 |                ▕          ░░░░░░█░░░░░               ▏
# EPISODE  13100 | Mean: 32.5, Highscore: 65 |          ▕                 ░░░░█░░░░░                     ▏
# EPISODE  13200 | Mean: 31.3, Highscore: 65 |               ▕           ░░░░█░░░░               ▏
# EPISODE  13300 | Mean: 33.1, Highscore: 73 |    ▕                       ░░░█░░░░░░                                   ▏
# EPISODE  13400 | Mean: 33.1, Highscore: 73 |                  ▕         ░░░░█░░░░               ▏
# EPISODE  13500 | Mean: 34.3, Highscore: 73 |                       ▕     ░░░░░░█░░░                      ▏
# EPISODE  13600 | Mean: 32.5, Highscore: 73 |    ▕                       ░░░░█░░░░░                 ▏
# EPISODE  13700 | Mean: 34.3, Highscore: 73 |           ▕                  ░░░░█░░░░              ▏
# EPISODE  13800 | Mean: 32.7, Highscore: 73 |              ▕             ░░░█░░░░░                        ▏
# EPISODE  13900 | Mean: 33.0, Highscore: 73 |   ▕                        ░░░░█░░░░░                   ▏
# EPISODE  14000 | Mean: 31.6, Highscore: 73 |     ▕                      ░░░░█░░░                ▏
# EPISODE  14100 | Mean: 32.4, Highscore: 73 |      ▕                    ░░░░░█░░░░                      ▏
# EPISODE  14200 | Mean: 33.9, Highscore: 73 |                  ▕         ░░░░░█░░░░░                   ▏
# EPISODE  14300 | Mean: 32.3, Highscore: 73 |                 ▕         ░░░░█░░░░░░               ▏
# EPISODE  14400 | Mean: 33.7, Highscore: 73 |      ▕                     ░░░░░░█░░░░                 ▏
# EPISODE  14500 | Mean: 32.6, Highscore: 73 |              ▕             ░░░░█░░░░                 ▏
# EPISODE  14600 | Mean: 33.6, Highscore: 73 |            ▕               ░░░░░█░░░░░░                    ▏
# EPISODE  14700 | Mean: 33.5, Highscore: 73 |  ▕                         ░░░░░░░█░░░                ▏
# EPISODE  14800 | Mean: 32.9, Highscore: 73 |                 ▕          ░░░░█░░░░░                    ▏
# EPISODE  14900 | Mean: 33.4, Highscore: 73 |                     ▕      ░░░░░█░░░                             ▏
# EPISODE  15000 | Mean: 32.3, Highscore: 73 |          ▕                 ░░░░█░░░░                      ▏
# EPISODE  15100 | Mean: 33.3, Highscore: 73 |   ▕                        ░░░░░█░░░░░                   ▏
# EPISODE  15200 | Mean: 33.7, Highscore: 73 |                ▕           ░░░░░█░░░░░                 ▏
# EPISODE  15300 | Mean: 33.9, Highscore: 73 |               ▕            ░░░░░█░░░░░                       ▏
# EPISODE  15400 | Mean: 33.9, Highscore: 73 |       ▕                    ░░░░░█░░░░░░             ▏
# EPISODE  15500 | Mean: 35.7, Highscore: 73 |              ▕               ░░░░░█░░░░░░                 ▏
# EPISODE  15600 | Mean: 32.5, Highscore: 73 |        ▕                   ░░░░░█░░░░             ▏
# EPISODE  15700 | Mean: 33.2, Highscore: 73 |         ▕                   ░░░░░█░░░░             ▏
# EPISODE  15800 | Mean: 33.6, Highscore: 73 |             ▕              ░░░░░░█░░░░                   ▏
# EPISODE  15900 | Mean: 34.8, Highscore: 73 |       ▕                     ░░░░░█░░░░░               ▏
# EPISODE  16000 | Mean: 33.9, Highscore: 73 |    ▕                         ░░░█░░░░░               ▏
# EPISODE  16100 | Mean: 34.7, Highscore: 73 |                 ▕            ░░░░░█░░░                    ▏
# EPISODE  16200 | Mean: 34.5, Highscore: 73 |                ▕             ░░░░█░░░░░            ▏
# EPISODE  16300 | Mean: 34.6, Highscore: 73 |       ▕                     ░░░░░█░░░░░                ▏
# EPISODE  16400 | Mean: 34.7, Highscore: 73 |                ▕            ░░░░░█░░░░░                            ▏
# EPISODE  16500 | Mean: 34.7, Highscore: 73 |             ▕                ░░░░█░░░░░░           ▏
# EPISODE  16600 | Mean: 35.8, Highscore: 73 |              ▕                ░░░░░█░░░░░                        ▏
# EPISODE  16700 | Mean: 35.2, Highscore: 73 |     ▕                        ░░░░░░█░░░░               ▏
# EPISODE  16800 | Mean: 34.3, Highscore: 73 |         ▕                    ░░░░█░░░░░              ▏
# EPISODE  16900 | Mean: 34.6, Highscore: 73 |      ▕                       ░░░░█░░░░░░                     ▏
# EPISODE  17000 | Mean: 34.3, Highscore: 73 |              ▕               ░░░░█░░░░               ▏
# EPISODE  17100 | Mean: 35.1, Highscore: 73 |    ▕                         ░░░░█░░░░░░░              ▏
# EPISODE  17200 | Mean: 35.8, Highscore: 73 |             ▕               ░░░░░░█░░░░░░░                 ▏
# EPISODE  17300 | Mean: 32.5, Highscore: 73 |    ▕                       ░░░░░░█░░░        ▏
# EPISODE  17400 | Mean: 33.8, Highscore: 73 |          ▕                  ░░░░░█░░░░              ▏
# EPISODE  17500 | Mean: 34.7, Highscore: 73 |       ▕                       ░░░█░░░░░              ▏
# EPISODE  17600 | Mean: 35.8, Highscore: 73 |     ▕                         ░░░░░█░░░░                      ▏
# EPISODE  17700 | Mean: 36.2, Highscore: 73 |               ▕              ░░░░░░█░░░░░             ▏
# EPISODE  17800 | Mean: 34.3, Highscore: 73 |      ▕                       ░░░░░█░░░░                  ▏
# EPISODE  17900 | Mean: 35.5, Highscore: 73 |     ▕                       ░░░░░░░█░░░░░░░          ▏
# EPISODE  18000 | Mean: 36.8, Highscore: 75 |         ▕                     ░░░░░█░░░░░░░                               ▏
# EPISODE  18100 | Mean: 37.3, Highscore: 75 |                  ▕             ░░░░░█░░░░                      ▏
# EPISODE  18200 | Mean: 35.1, Highscore: 75 |                  ▕          ░░░░░░█░░░░░            ▏
# EPISODE  18300 | Mean: 36.2, Highscore: 75 |                   ▕           ░░░░░░█░░░░             ▏
# EPISODE  18400 | Mean: 36.4, Highscore: 75 |                    ▕          ░░░░░█░░░░░                     ▏
# EPISODE  18500 | Mean: 35.7, Highscore: 75 |    ▕                           ░░░░█░░░░               ▏
# EPISODE  18600 | Mean: 34.9, Highscore: 75 |        ▕                    ░░░░░█░░░░░░                     ▏
# EPISODE  18700 | Mean: 34.4, Highscore: 75 |                ▕            ░░░░░█░░░░░░                      ▏
# EPISODE  18800 | Mean: 37.0, Highscore: 75 |                       ▕       ░░░░░█░░░░░░               ▏
# EPISODE  18900 | Mean: 36.7, Highscore: 75 |           ▕                   ░░░░░░█░░░░░                 ▏
# EPISODE  19000 | Mean: 36.2, Highscore: 75 |        ▕                      ░░░░░█░░░░               ▏
# EPISODE  19100 | Mean: 34.5, Highscore: 75 |        ▕                    ░░░░░█░░░░░                  ▏
# EPISODE  19200 | Mean: 36.6, Highscore: 75 |          ▕                     ░░░░░█░░░░░                           ▏
# EPISODE  19300 | Mean: 36.0, Highscore: 75 |         ▕                     ░░░░░░█░░░                  ▏
# EPISODE  19400 | Mean: 36.1, Highscore: 75 |               ▕               ░░░░░█░░░░░                      ▏
# EPISODE  19500 | Mean: 36.2, Highscore: 75 |        ▕                      ░░░░░█░░░░░░             ▏
# EPISODE  19600 | Mean: 36.1, Highscore: 75 |    ▕                        ░░░░░░░█░░░░░░            ▏
# EPISODE  19700 | Mean: 34.9, Highscore: 75 |               ▕              ░░░░░█░░░░            ▏
# EPISODE  19800 | Mean: 36.4, Highscore: 75 |                ▕              ░░░░░█░░░░░                         ▏
# EPISODE  19900 | Mean: 34.8, Highscore: 75 |              ▕               ░░░░░█░░░░░░         ▏
# EPISODE  20000 | Mean: 35.5, Highscore: 75 |      ▕                       ░░░░░░█░░░░                         ▏
# EPISODE  20100 | Mean: 34.4, Highscore: 75 |      ▕                       ░░░░░░█░░░░             ▏
# EPISODE  20200 | Mean: 33.3, Highscore: 75 |▕                             ░░░░█░░░                ▏
# EPISODE  20300 | Mean: 33.7, Highscore: 75 |       ▕                      ░░░░█░░░░░              ▏
# EPISODE  20400 | Mean: 33.2, Highscore: 75 |     ▕                      ░░░░░█░░░░░                ▏
# EPISODE  20500 | Mean: 33.6, Highscore: 75 |            ▕               ░░░░░░█░░░░░         ▏
# EPISODE  20600 | Mean: 34.3, Highscore: 75 |             ▕               ░░░░░█░░░░░░              ▏
# EPISODE  20700 | Mean: 34.6, Highscore: 75 |    ▕                          ░░░░█░░░░                 ▏
# EPISODE  20800 | Mean: 35.5, Highscore: 75 |     ▕                        ░░░░░░█░░░░░                   ▏
# EPISODE  20900 | Mean: 36.9, Highscore: 75 |                     ▕          ░░░░█░░░░░             ▏
# EPISODE  21000 | Mean: 36.0, Highscore: 75 |                   ▕           ░░░░░█░░░░                  ▏
# EPISODE  21100 | Mean: 34.5, Highscore: 75 |              ▕              ░░░░░█░░░░░                   ▏
# EPISODE  21200 | Mean: 35.4, Highscore: 75 |               ▕             ░░░░░░░█░░░░                     ▏
# EPISODE  21300 | Mean: 35.0, Highscore: 75 |       ▕                      ░░░░░░█░░░░           ▏
# EPISODE  21400 | Mean: 36.1, Highscore: 75 |         ▕                      ░░░░░█░░░░               ▏
# EPISODE  21500 | Mean: 34.7, Highscore: 75 |                  ▕           ░░░░░░█░░░            ▏
# EPISODE  21600 | Mean: 36.5, Highscore: 75 |                    ▕           ░░░░█░░░░░           ▏
# EPISODE  21700 | Mean: 36.2, Highscore: 75 |          ▕                     ░░░░█░░░░░              ▏
# EPISODE  21800 | Mean: 35.7, Highscore: 75 |  ▕                           ░░░░░░█░░░░░                      ▏
# EPISODE  21900 | Mean: 36.5, Highscore: 75 |  ▕                             ░░░░░█░░░░              ▏
# EPISODE  22000 | Mean: 35.7, Highscore: 75 | ▕                              ░░░░█░░░░░                ▏
# EPISODE  22100 | Mean: 35.7, Highscore: 75 |            ▕                  ░░░░░█░░░░           ▏
# EPISODE  22200 | Mean: 36.5, Highscore: 75 |         ▕                       ░░░█░░░░            ▏
# EPISODE  22300 | Mean: 34.9, Highscore: 75 | ▕                            ░░░░░█░░░░░░               ▏
# EPISODE  22400 | Mean: 34.3, Highscore: 75 |         ▕                    ░░░░█░░░░░                  ▏
# EPISODE  22500 | Mean: 36.0, Highscore: 75 |        ▕                       ░░░░█░░░░░             ▏
# EPISODE  22600 | Mean: 36.1, Highscore: 75 |             ▕                  ░░░░█░░░                   ▏
# EPISODE  22700 | Mean: 35.2, Highscore: 75 |       ▕                       ░░░░░█░░░               ▏
# EPISODE  22800 | Mean: 35.0, Highscore: 75 |                  ▕            ░░░░░█░░░                 ▏
# EPISODE  22900 | Mean: 36.9, Highscore: 75 |                  ▕              ░░░░█░░░░             ▏
# EPISODE  23000 | Mean: 35.5, Highscore: 75 |               ▕              ░░░░░░█░░░░               ▏
# EPISODE  23100 | Mean: 37.5, Highscore: 75 |                       ▕         ░░░█░░░░░░                 ▏
# EPISODE  23200 | Mean: 32.8, Highscore: 75 |   ▕                        ░░░░░░█░░░░         ▏
# EPISODE  23300 | Mean: 33.2, Highscore: 75 |   ▕                         ░░░░░█░░░░              ▏
# EPISODE  23400 | Mean: 35.5, Highscore: 75 |     ▕                         ░░░░░█░░░░                  ▏
# EPISODE  23500 | Mean: 34.8, Highscore: 75 |      ▕                        ░░░░█░░░░             ▏
# EPISODE  23600 | Mean: 35.3, Highscore: 75 |              ▕                ░░░░█░░░░░            ▏
# EPISODE  23700 | Mean: 36.8, Highscore: 75 |             ▕                  ░░░░░█░░░░░             ▏
# EPISODE  23800 | Mean: 36.6, Highscore: 75 |                     ▕          ░░░░█░░░░                ▏
# EPISODE  23900 | Mean: 35.1, Highscore: 75 |            ▕                  ░░░░█░░░               ▏
# EPISODE  24000 | Mean: 35.0, Highscore: 75 |       ▕                         ░░░█░░░              ▏
# EPISODE  24100 | Mean: 35.2, Highscore: 75 |         ▕                    ░░░░░░█░░░░                         ▏
# EPISODE  24200 | Mean: 36.1, Highscore: 75 |              ▕                ░░░░░█░░░░░                      ▏
# EPISODE  24300 | Mean: 35.8, Highscore: 75 |              ▕                  ░░░░█░░░              ▏
# EPISODE  24400 | Mean: 35.2, Highscore: 75 |        ▕                      ░░░░░█░░░░            ▏
# EPISODE  24500 | Mean: 37.9, Highscore: 75 |               ▕                ░░░░░█░░░░░░              ▏
# EPISODE  24600 | Mean: 34.9, Highscore: 75 |         ▕                    ░░░░░░█░░░                   ▏
# EPISODE  24700 | Mean: 35.2, Highscore: 75 |       ▕                      ░░░░░░█░░░░            ▏
# EPISODE  24800 | Mean: 38.1, Highscore: 75 |               ▕                  ░░░░█░░░░░              ▏
# EPISODE  24900 | Mean: 36.0, Highscore: 75 |          ▕                    ░░░░░█░░░░               ▏
# EPISODE  25000 | Mean: 34.7, Highscore: 75 |          ▕                   ░░░░░░█░░░                  ▏
# EPISODE  25100 | Mean: 35.2, Highscore: 75 |          ▕                    ░░░░░█░░░░               ▏
# EPISODE  25200 | Mean: 35.5, Highscore: 75 |       ▕                        ░░░░█░░░░              ▏
# EPISODE  25300 | Mean: 35.8, Highscore: 75 |              ▕                 ░░░░█░░░░          ▏
# EPISODE  25400 | Mean: 35.6, Highscore: 75 |   ▕                            ░░░░█░░░░░                ▏
# EPISODE  25500 | Mean: 36.9, Highscore: 75 |       ▕                        ░░░░█░░░░░                ▏
# EPISODE  25600 | Mean: 35.2, Highscore: 75 |              ▕                ░░░░░█░░░           ▏
# EPISODE  25700 | Mean: 36.0, Highscore: 75 |               ▕                ░░░░░█░░░               ▏
# EPISODE  25800 | Mean: 36.8, Highscore: 75 |                    ▕            ░░░█░░░░░              ▏
# EPISODE  25900 | Mean: 36.1, Highscore: 75 |      ▕                          ░░░█░░░░          ▏
# EPISODE  26000 | Mean: 35.6, Highscore: 75 |             ▕                  ░░░░█░░░░             ▏
# EPISODE  26100 | Mean: 35.7, Highscore: 75 |               ▕                ░░░░█░░░░         ▏
# EPISODE  26200 | Mean: 34.9, Highscore: 75 |                   ▕          ░░░░░░█░░░░         ▏
# EPISODE  26300 | Mean: 38.2, Highscore: 75 |▕                                 ░░░░█░░░░░░              ▏
# EPISODE  26400 | Mean: 37.0, Highscore: 75 |  ▕                              ░░░░░█░░░               ▏
# EPISODE  26500 | Mean: 36.4, Highscore: 75 |                 ▕             ░░░░░█░░░░░             ▏
# EPISODE  26600 | Mean: 35.6, Highscore: 75 |               ▕              ░░░░░░█░░░░              ▏
# EPISODE  26700 | Mean: 35.0, Highscore: 75 |  ▕                             ░░░░█░░░░      ▏
# EPISODE  26800 | Mean: 36.1, Highscore: 75 |                ▕               ░░░░█░░░░               ▏
# EPISODE  26900 | Mean: 36.6, Highscore: 75 |           ▕                     ░░░░█░░░░░              ▏
# EPISODE  27000 | Mean: 38.2, Highscore: 75 |              ▕                   ░░░█░░░░░░             ▏
# EPISODE  27100 | Mean: 37.6, Highscore: 75 |     ▕                           ░░░░░█░░░                    ▏
# EPISODE  27200 | Mean: 37.1, Highscore: 75 |                     ▕          ░░░░░█░░░░                ▏
# EPISODE  27300 | Mean: 37.3, Highscore: 75 |                     ▕           ░░░░█░░░░                     ▏
# EPISODE  27400 | Mean: 37.4, Highscore: 75 |                       ▕        ░░░░░█░░░░░            ▏
# EPISODE  27500 | Mean: 37.4, Highscore: 75 |                     ▕          ░░░░░░█░░░░             ▏
# EPISODE  27600 | Mean: 38.3, Highscore: 75 |                  ▕                 ░░█░░░░░        ▏
# EPISODE  27700 | Mean: 36.6, Highscore: 75 |             ▕                   ░░░█░░░░░            ▏
# EPISODE  27800 | Mean: 37.4, Highscore: 75 |                    ▕            ░░░░█░░░░                  ▏
# EPISODE  27900 | Mean: 35.6, Highscore: 75 |            ▕                  ░░░░░█░░░░                ▏
# EPISODE  28000 | Mean: 34.1, Highscore: 75 |   ▕                         ░░░░░░█░░░░░░        ▏
# EPISODE  28100 | Mean: 36.1, Highscore: 75 |               ▕               ░░░░█░░░░░░            ▏
# EPISODE  28200 | Mean: 35.6, Highscore: 75 |               ▕                ░░░░█░░░░                     ▏
# EPISODE  28300 | Mean: 37.0, Highscore: 75 |               ▕                ░░░░░░█░░░░░          ▏
# EPISODE  28400 | Mean: 35.2, Highscore: 75 |       ▕                        ░░░█░░░░              ▏
# EPISODE  28500 | Mean: 35.8, Highscore: 75 |    ▕                          ░░░░░░█░░░          ▏
# EPISODE  28600 | Mean: 36.7, Highscore: 75 |   ▕                            ░░░░░█░░░░░              ▏
# EPISODE  28700 | Mean: 35.1, Highscore: 75 |   ▕                           ░░░░░█░░░                ▏
# EPISODE  28800 | Mean: 36.4, Highscore: 75 |      ▕                           ░░░█░░░           ▏
# EPISODE  28900 | Mean: 34.8, Highscore: 75 |▕                             ░░░░░░░█░░░                   ▏
# EPISODE  29000 | Mean: 36.4, Highscore: 75 |             ▕                  ░░░░░█░░░             ▏
# EPISODE  29100 | Mean: 38.4, Highscore: 75 |                    ▕             ░░░░█░░░░░                 ▏
# EPISODE  29200 | Mean: 36.3, Highscore: 75 |  ▕                               ░░░░█░░░░              ▏
# EPISODE  29300 | Mean: 35.5, Highscore: 75 |                     ▕         ░░░░█░░░░░         ▏
# EPISODE  29400 | Mean: 36.0, Highscore: 75 |                      ▕         ░░░░█░░░░         ▏
# EPISODE  29500 | Mean: 35.5, Highscore: 75 |     ▕                         ░░░░░█░░░░             ▏
# EPISODE  29600 | Mean: 37.6, Highscore: 75 |                     ▕            ░░░█░░░░              ▏
# EPISODE  29700 | Mean: 36.7, Highscore: 75 |                       ▕         ░░░░█░░░               ▏
# EPISODE  29800 | Mean: 36.0, Highscore: 75 | ▕                                ░░░█░░░             ▏
# EPISODE  29900 | Mean: 36.1, Highscore: 75 |            ▕                   ░░░░░█░░░░                  ▏
# EPISODE  30000 | Mean: 34.6, Highscore: 75 |  ▕                           ░░░░█░░░░░░                ▏
# EPISODE  30100 | Mean: 36.7, Highscore: 75 | ▕                                ░░█░░░░              ▏
# EPISODE  30200 | Mean: 36.7, Highscore: 75 |   ▕                           ░░░░░░█░░░░                  ▏
# EPISODE  30300 | Mean: 35.7, Highscore: 75 |                      ▕       ░░░░░░█░░░░                ▏
# EPISODE  30400 | Mean: 34.5, Highscore: 75 |   ▕                          ░░░░░█░░░                  ▏
# EPISODE  30500 | Mean: 36.4, Highscore: 75 |   ▕                            ░░░░█░░░░░                ▏
# EPISODE  30600 | Mean: 36.8, Highscore: 75 |              ▕                  ░░░█░░░░             ▏
# EPISODE  30700 | Mean: 37.0, Highscore: 75 |                       ▕        ░░░░░█░░░            ▏
# EPISODE  30800 | Mean: 36.4, Highscore: 75 |               ▕                 ░░░░█░░               ▏
# EPISODE  30900 | Mean: 35.6, Highscore: 75 |         ▕                    ░░░░░█░░░░░            ▏
# EPISODE  31000 | Mean: 35.3, Highscore: 75 |                 ▕              ░░░░█░░░            ▏
# EPISODE  31100 | Mean: 37.1, Highscore: 75 |                  ▕             ░░░░░█░░░                     ▏
# EPISODE  31200 | Mean: 36.7, Highscore: 75 |                   ▕            ░░░░█░░░░░            ▏
# EPISODE  31300 | Mean: 35.9, Highscore: 75 |▕                             ░░░░░░░█░░░░░             ▏
# EPISODE  31400 | Mean: 37.9, Highscore: 75 |                   ▕             ░░░░█░░░░░░                 ▏
# EPISODE  31500 | Mean: 37.3, Highscore: 75 |            ▕                    ░░░░█░░░░░                 ▏
# EPISODE  31600 | Mean: 35.1, Highscore: 75 |   ▕                           ░░░░░█░░░                ▏
# EPISODE  31700 | Mean: 35.2, Highscore: 75 |      ▕                        ░░░░░█░░░░           ▏
# EPISODE  31800 | Mean: 37.4, Highscore: 75 |                   ▕            ░░░░░█░░░░░               ▏
# EPISODE  31900 | Mean: 35.3, Highscore: 75 |           ▕                    ░░░░█░░░                   ▏
# EPISODE  32000 | Mean: 37.1, Highscore: 75 |                      ▕         ░░░░░█░░░░              ▏
# EPISODE  32100 | Mean: 35.9, Highscore: 75 |                  ▕             ░░░░█░░░              ▏
# EPISODE  32200 | Mean: 37.6, Highscore: 75 |                     ▕           ░░░░█░░░░░                 ▏
# EPISODE  32300 | Mean: 36.5, Highscore: 75 |         ▕                      ░░░░░░█░░░         ▏
# EPISODE  32400 | Mean: 36.8, Highscore: 75 |▕                                 ░░░█░░░                  ▏
# EPISODE  32500 | Mean: 35.5, Highscore: 75 |              ▕                ░░░░░░█░░░░       ▏
# EPISODE  32600 | Mean: 34.7, Highscore: 75 |          ▕                    ░░░░░█░░░       ▏
# EPISODE  32700 | Mean: 36.3, Highscore: 75 |               ▕                 ░░░░█░░░              ▏
# EPISODE  32800 | Mean: 35.8, Highscore: 75 |              ▕               ░░░░░░█░░░░                ▏
# EPISODE  32900 | Mean: 35.9, Highscore: 75 |       ▕                       ░░░░░█░░░░                            ▏
# EPISODE  33000 | Mean: 36.1, Highscore: 75 |                  ▕              ░░░█░░░░           ▏
# EPISODE  33100 | Mean: 35.6, Highscore: 75 |             ▕                 ░░░░░█░░░░░                 ▏
# EPISODE  33200 | Mean: 36.4, Highscore: 75 |                   ▕           ░░░░░█░░░░░░          ▏
# EPISODE  33300 | Mean: 35.8, Highscore: 75 |     ▕                         ░░░░░█░░░░░              ▏
# EPISODE  33400 | Mean: 36.7, Highscore: 75 |             ▕                  ░░░░░█░░░░░           ▏
# EPISODE  33500 | Mean: 36.2, Highscore: 75 |  ▕                               ░░█░░░░              ▏
# EPISODE  33600 | Mean: 36.9, Highscore: 75 |    ▕                           ░░░░░░█░░░                               ▏
# EPISODE  33700 | Mean: 37.1, Highscore: 75 |               ▕                 ░░░░░█░░░░            ▏
# EPISODE  33800 | Mean: 37.4, Highscore: 75 |             ▕                   ░░░░░█░░░           ▏
# EPISODE  33900 | Mean: 36.1, Highscore: 75 |                     ▕          ░░░░█░░░░░           ▏
# EPISODE  34000 | Mean: 37.1, Highscore: 75 |     ▕                            ░░░░█░░░░            ▏
# EPISODE  34100 | Mean: 37.0, Highscore: 75 |             ▕                   ░░░░█░░░░            ▏
# EPISODE  34200 | Mean: 36.6, Highscore: 75 |           ▕                     ░░░░█░░░                ▏
# EPISODE  34300 | Mean: 36.1, Highscore: 75 |       ▕                        ░░░░█░░░░░                    ▏
# EPISODE  34400 | Mean: 36.7, Highscore: 75 |                ▕               ░░░░░█░░░                 ▏
# EPISODE  34500 | Mean: 36.9, Highscore: 75 |  ▕                              ░░░░█░░░░░             ▏
# EPISODE  34600 | Mean: 36.0, Highscore: 75 |      ▕                         ░░░░█░░░                   ▏
# EPISODE  34700 | Mean: 36.0, Highscore: 75 |         ▕                     ░░░░░█░░░░            ▏
# EPISODE  34800 | Mean: 36.7, Highscore: 75 | ▕                               ░░░░█░░░░              ▏
# EPISODE  34900 | Mean: 37.8, Highscore: 75 |                   ▕             ░░░░░█░░░░                    ▏
# EPISODE  35000 | Mean: 37.1, Highscore: 75 |                     ▕           ░░░░█░░░                  ▏
# EPISODE  35100 | Mean: 35.3, Highscore: 75 |                 ▕             ░░░░█░░░░            ▏
# EPISODE  35200 | Mean: 37.8, Highscore: 75 |            ▕                    ░░░░░█░░░░                  ▏
# EPISODE  35300 | Mean: 37.3, Highscore: 75 |                  ▕             ░░░░░█░░░░                   ▏
# EPISODE  35400 | Mean: 37.0, Highscore: 75 |            ▕                   ░░░░░░█░░░░         ▏
# EPISODE  35500 | Mean: 36.3, Highscore: 75 |                     ▕          ░░░░░░█░░░            ▏
# EPISODE  35600 | Mean: 36.4, Highscore: 75 |                       ▕        ░░░░░█░░░░░               ▏
# EPISODE  35700 | Mean: 34.5, Highscore: 75 |    ▕                         ░░░░█░░░░░                   ▏
# EPISODE  35800 | Mean: 36.8, Highscore: 75 |          ▕                       ░░░█░░░              ▏
# EPISODE  35900 | Mean: 36.0, Highscore: 75 |             ▕                   ░░░█░░░░            ▏
# EPISODE  36000 | Mean: 36.9, Highscore: 75 |                 ▕               ░░░░█░░░░                 ▏
# EPISODE  36100 | Mean: 37.9, Highscore: 75 |                 ▕              ░░░░░░█░░░░░░                   ▏
# EPISODE  36200 | Mean: 36.3, Highscore: 75 |       ▕                      ░░░░░░░█░░░░               ▏
# EPISODE  36300 | Mean: 36.8, Highscore: 75 |             ▕                    ░░░█░░░           ▏
# EPISODE  36400 | Mean: 36.7, Highscore: 75 |      ▕                         ░░░░█░░░░░                      ▏
# EPISODE  36500 | Mean: 36.1, Highscore: 75 |              ▕                 ░░░░░█░░░                ▏
# EPISODE  36600 | Mean: 37.9, Highscore: 75 |                   ▕              ░░░░█░░░░░          ▏
# EPISODE  36700 | Mean: 36.0, Highscore: 75 |    ▕                           ░░░░█░░░░░              ▏
# EPISODE  36800 | Mean: 35.1, Highscore: 75 |           ▕                    ░░░░█░░░            ▏
# EPISODE  36900 | Mean: 35.2, Highscore: 75 |                  ▕             ░░░░█░░░                  ▏
# EPISODE  37000 | Mean: 35.9, Highscore: 75 |                  ▕             ░░░░█░░░░             ▏
# EPISODE  37100 | Mean: 35.9, Highscore: 75 |         ▕                      ░░░░█░░░░         ▏
# EPISODE  37200 | Mean: 37.6, Highscore: 75 |           ▕                      ░░░░█░░░░              ▏
# EPISODE  37300 | Mean: 36.0, Highscore: 75 |          ▕                     ░░░░█░░░░                ▏
# EPISODE  37400 | Mean: 37.6, Highscore: 75 |            ▕                   ░░░░░░█░░░░                 ▏
# EPISODE  37500 | Mean: 34.8, Highscore: 75 |       ▕                      ░░░░░░█░░░          ▏
# EPISODE  37600 | Mean: 37.5, Highscore: 75 |  ▕                               ░░░░█░░░░                 ▏
# EPISODE  37700 | Mean: 36.6, Highscore: 75 |   ▕                           ░░░░░░█░░░░                  ▏
# EPISODE  37800 | Mean: 35.5, Highscore: 75 |                   ▕           ░░░░░█░░░░         ▏
# EPISODE  37900 | Mean: 35.8, Highscore: 75 |        ▕                       ░░░░░█░░░                 ▏
# EPISODE  38000 | Mean: 37.1, Highscore: 75 |            ▕                   ░░░░░█░░░░░                  ▏
# EPISODE  38100 | Mean: 35.6, Highscore: 75 |                    ▕         ░░░░░░█░░░                       ▏
# EPISODE  38200 | Mean: 36.5, Highscore: 75 |                   ▕            ░░░░█░░░░░░             ▏
# EPISODE  38300 | Mean: 37.1, Highscore: 75 |             ▕                    ░░░█░░░░               ▏
# EPISODE  38400 | Mean: 34.7, Highscore: 75 |      ▕                       ░░░░░░█░░░             ▏
# EPISODE  38500 | Mean: 36.8, Highscore: 75 |          ▕                     ░░░░█░░░░              ▏
# EPISODE  38600 | Mean: 35.6, Highscore: 75 |                   ▕            ░░░░█░░░              ▏
# EPISODE  38700 | Mean: 36.7, Highscore: 75 |                   ▕            ░░░░█░░░░                 ▏
# EPISODE  38800 | Mean: 37.2, Highscore: 75 |                 ▕              ░░░░░█░░░░░░░             ▏
# EPISODE  38900 | Mean: 36.5, Highscore: 75 |                      ▕         ░░░░█░░░░               ▏
# EPISODE  39000 | Mean: 35.9, Highscore: 75 |           ▕                    ░░░░█░░░░                ▏
# EPISODE  39100 | Mean: 36.7, Highscore: 75 |                 ▕              ░░░░█░░░░░░            ▏
# EPISODE  39200 | Mean: 36.0, Highscore: 75 |▕                               ░░░░█░░░░           ▏
# EPISODE  39300 | Mean: 36.7, Highscore: 75 |                 ▕              ░░░░█░░░░░                     ▏
# EPISODE  39400 | Mean: 37.6, Highscore: 75 |                     ▕            ░░░░█░░░░              ▏
# EPISODE  39500 | Mean: 36.4, Highscore: 75 |                     ▕        ░░░░░░░█░░░░            ▏
# EPISODE  39600 | Mean: 37.4, Highscore: 75 |              ▕                  ░░░░░█░░░░              ▏
# EPISODE  39700 | Mean: 37.4, Highscore: 75 |              ▕                  ░░░░█░░░░░         ▏
# EPISODE  39800 | Mean: 37.5, Highscore: 75 |                 ▕               ░░░░░█░░░░░       ▏
# EPISODE  39900 | Mean: 35.5, Highscore: 75 |   ▕                           ░░░░░░█░░░         ▏
# EPISODE  40000 | Mean: 35.8, Highscore: 75 |     ▕                        ░░░░░░█░░░░            ▏
# EPISODE  40100 | Mean: 36.9, Highscore: 75 |             ▕                   ░░░█░░░░░                    ▏
# EPISODE  40200 | Mean: 36.9, Highscore: 75 |                 ▕              ░░░░█░░░░░             ▏
# EPISODE  40300 | Mean: 38.9, Highscore: 75 |   ▕                              ░░░░░█░░░░░         ▏
# EPISODE  40400 | Mean: 38.0, Highscore: 75 |                     ▕            ░░░█░░░░░            ▏
# EPISODE  40500 | Mean: 35.5, Highscore: 75 |              ▕                ░░░░░█░░░░          ▏
# EPISODE  40600 | Mean: 38.2, Highscore: 75 |           ▕                     ░░░░░█░░░░               ▏
# EPISODE  40700 | Mean: 38.1, Highscore: 75 |      ▕                         ░░░░░░░█░░░░░            ▏
# EPISODE  40800 | Mean: 37.1, Highscore: 75 |                   ▕            ░░░░░█░░░░                ▏
# EPISODE  40900 | Mean: 34.3, Highscore: 75 |             ▕                ░░░░░█░░░░         ▏
# EPISODE  41000 | Mean: 35.6, Highscore: 75 |         ▕                    ░░░░░░█░░░░░              ▏
# EPISODE  41100 | Mean: 36.8, Highscore: 75 |         ▕                       ░░░█░░░░░              ▏
# EPISODE  41200 | Mean: 38.1, Highscore: 75 |                       ▕         ░░░░░█░░░░           ▏
# EPISODE  41300 | Mean: 34.7, Highscore: 75 |    ▕                        ░░░░░█░░░░░░                 ▏
# EPISODE  41400 | Mean: 36.8, Highscore: 75 |      ▕                          ░░░░█░░░░               ▏
# EPISODE  41500 | Mean: 37.0, Highscore: 75 |                       ▕         ░░░░█░░░             ▏
# EPISODE  41600 | Mean: 37.2, Highscore: 75 |                     ▕            ░░░░█░░░                  ▏
# EPISODE  41700 | Mean: 36.5, Highscore: 75 |       ▕                        ░░░░█░░░░░                  ▏
# EPISODE  41800 | Mean: 36.6, Highscore: 75 |      ▕                         ░░░░░█░░░░░            ▏
# EPISODE  41900 | Mean: 35.2, Highscore: 75 |    ▕                          ░░░░░█░░░░           ▏
# EPISODE  42000 | Mean: 37.3, Highscore: 75 |                  ▕             ░░░░░█░░░░░░             ▏
# EPISODE  42100 | Mean: 37.9, Highscore: 75 |                      ▕           ░░░█░░░░                     ▏
# EPISODE  42200 | Mean: 37.3, Highscore: 75 |      ▕                         ░░░░░█░░░░░░          ▏
# EPISODE  42300 | Mean: 37.4, Highscore: 75 |           ▕                    ░░░░░░█░░░░░         ▏
# EPISODE  42400 | Mean: 38.0, Highscore: 75 |                 ▕               ░░░░░█░░░░              ▏
# EPISODE  42500 | Mean: 35.9, Highscore: 75 |                 ▕              ░░░░█░░░░                ▏
# EPISODE  42600 | Mean: 37.4, Highscore: 75 |               ▕                 ░░░░█░░░░░              ▏
# EPISODE  42700 | Mean: 35.4, Highscore: 75 |                  ▕           ░░░░░█░░░░░                  ▏
# EPISODE  42800 | Mean: 35.6, Highscore: 75 |    ▕                           ░░░░█░░░░░              ▏
# EPISODE  42900 | Mean: 36.1, Highscore: 75 |                    ▕           ░░░░█░░░░░               ▏
# EPISODE  43000 | Mean: 37.0, Highscore: 75 |                     ▕          ░░░░░█░░░░                ▏
# EPISODE  43100 | Mean: 37.1, Highscore: 75 |            ▕                     ░░░█░░░░               ▏
# EPISODE  43200 | Mean: 36.4, Highscore: 75 |                     ▕           ░░░█░░░░               ▏
# EPISODE  43300 | Mean: 35.5, Highscore: 75 |              ▕                ░░░░░█░░░                ▏
# EPISODE  43400 | Mean: 37.7, Highscore: 75 |           ▕                     ░░░░░█░░░░░               ▏
# EPISODE  43500 | Mean: 36.0, Highscore: 75 |              ▕               ░░░░░░█░░░░                 ▏
# EPISODE  43600 | Mean: 37.5, Highscore: 75 |                ▕                ░░░░█░░░░               ▏
# EPISODE  43700 | Mean: 35.9, Highscore: 75 |  ▕                              ░░░█░░░░░        ▏
# EPISODE  43800 | Mean: 37.3, Highscore: 75 |                     ▕           ░░░░█░░░░                 ▏
# EPISODE  43900 | Mean: 37.6, Highscore: 75 |          ▕                      ░░░░█░░░░░░                ▏
# EPISODE  44000 | Mean: 36.5, Highscore: 75 |                       ▕       ░░░░░█░░░░░                 ▏
# EPISODE  44100 | Mean: 37.0, Highscore: 75 |                ▕                ░░░░█░░░░              ▏
# EPISODE  44200 | Mean: 37.6, Highscore: 75 |                       ▕        ░░░░░█░░░░░             ▏
# EPISODE  44300 | Mean: 37.9, Highscore: 75 | ▕                               ░░░░░█░░░░                       ▏
# EPISODE  44400 | Mean: 35.8, Highscore: 75 |          ▕                     ░░░░█░░░                ▏
# EPISODE  44500 | Mean: 38.2, Highscore: 75 |         ▕                       ░░░░░█░░░░░              ▏
# EPISODE  44600 | Mean: 36.9, Highscore: 75 |                  ▕              ░░░░█░░░░░              ▏
# EPISODE  44700 | Mean: 36.8, Highscore: 75 |                     ▕          ░░░░░█░░░░             ▏
# EPISODE  44800 | Mean: 37.0, Highscore: 75 |          ▕                       ░░░█░░░                   ▏
# EPISODE  44900 | Mean: 36.3, Highscore: 75 |             ▕                   ░░░█░░░░              ▏
# EPISODE  45000 | Mean: 36.4, Highscore: 75 |                      ▕         ░░░░█░░░░            ▏
# EPISODE  45100 | Mean: 36.8, Highscore: 75 |                      ▕         ░░░░░█░░░░                    ▏
# EPISODE  45200 | Mean: 36.2, Highscore: 75 |                   ▕            ░░░░█░░░░             ▏
# EPISODE  45300 | Mean: 36.8, Highscore: 75 |              ▕                  ░░░░░█░░░                  ▏
# EPISODE  45400 | Mean: 37.4, Highscore: 75 |            ▕                    ░░░░█░░░░░                ▏
# EPISODE  45500 | Mean: 35.2, Highscore: 75 |  ▕                           ░░░░░░█░░░                ▏
# EPISODE  45600 | Mean: 34.5, Highscore: 75 |▕                             ░░░░░█░░░░░        ▏
# EPISODE  45700 | Mean: 36.5, Highscore: 75 |    ▕                            ░░░░█░░░                ▏
# EPISODE  45800 | Mean: 35.9, Highscore: 75 |             ▕                   ░░░█░░░░░      ▏
# EPISODE  45900 | Mean: 36.4, Highscore: 75 |       ▕                      ░░░░░░░█░░░░                 ▏
# EPISODE  46000 | Mean: 39.3, Highscore: 75 |                       ▕          ░░░░░█░░░░░░          ▏
# EPISODE  46100 | Mean: 38.5, Highscore: 75 |                     ▕          ░░░░░░█░░░░░░              ▏
# EPISODE  46200 | Mean: 36.9, Highscore: 75 |               ▕                ░░░░░█░░░░░                     ▏
# EPISODE  46300 | Mean: 36.0, Highscore: 75 |             ▕                 ░░░░█░░░░░░░              ▏
# EPISODE  46400 | Mean: 37.3, Highscore: 75 |             ▕                    ░░░█░░░░             ▏
# EPISODE  46500 | Mean: 37.6, Highscore: 75 |                     ▕           ░░░░█░░░░░░                 ▏
# EPISODE  46600 | Mean: 36.3, Highscore: 75 |                 ▕               ░░░░█░░░                    ▏
# EPISODE  46700 | Mean: 35.9, Highscore: 75 |           ▕                   ░░░░░█░░░░             ▏
# EPISODE  46800 | Mean: 36.4, Highscore: 75 | ▕                              ░░░░░█░░░░░            ▏
# EPISODE  46900 | Mean: 38.1, Highscore: 75 |                       ▕          ░░░█░░░░░                          ▏
# EPISODE  47000 | Mean: 37.1, Highscore: 75 |            ▕                   ░░░░░█░░░░              ▏
# EPISODE  47100 | Mean: 35.7, Highscore: 75 |                     ▕         ░░░░░░█░░░                 ▏
# EPISODE  47200 | Mean: 34.3, Highscore: 75 |               ▕             ░░░░░█░░░░░          ▏
# EPISODE  47300 | Mean: 34.4, Highscore: 75 |       ▕                     ░░░░░█░░░░░░               ▏
# EPISODE  47400 | Mean: 37.2, Highscore: 75 |                       ▕        ░░░░█░░░░░░              ▏
# EPISODE  47500 | Mean: 38.6, Highscore: 75 |                ▕                 ░░░░█░░░░░               ▏
# EPISODE  47600 | Mean: 37.9, Highscore: 75 |                    ▕            ░░░░░░█░░░░           ▏
# EPISODE  47700 | Mean: 38.8, Highscore: 75 |        ▕                          ░░░█░░░░░                 ▏
# EPISODE  47800 | Mean: 37.9, Highscore: 75 |                 ▕                ░░░█░░░░░                  ▏
# EPISODE  47900 | Mean: 37.9, Highscore: 75 |             ▕                    ░░░░█░░░               ▏
# EPISODE  48000 | Mean: 37.6, Highscore: 75 |         ▕                       ░░░░░█░░░                ▏
# EPISODE  48100 | Mean: 38.1, Highscore: 75 |             ▕                   ░░░░░█░░░░                     ▏
# EPISODE  48200 | Mean: 36.3, Highscore: 75 |      ▕                          ░░░█░░░░░                ▏
# EPISODE  48300 | Mean: 37.8, Highscore: 75 |  ▕                               ░░░░█░░░░░░            ▏
# EPISODE  48400 | Mean: 36.9, Highscore: 75 |                   ▕              ░░░█░░░           ▏
# ...
# EPISODE  84700 | Mean: 39.4, Highscore: 75 |                     ▕             ░░░░░█░░░░░░               ▏
# EPISODE  84800 | Mean: 37.1, Highscore: 75 |       ▕                       ░░░░░░█░░░░░                ▏
# EPISODE  84900 | Mean: 36.5, Highscore: 75 |            ▕                    ░░░█░░░░░              ▏
# EPISODE  85000 | Mean: 35.5, Highscore: 75 |           ▕                    ░░░░█░░░                ▏
# EPISODE  85100 | Mean: 36.6, Highscore: 75 |                   ▕           ░░░░░░█░░                    ▏
# EPISODE  85200 | Mean: 35.6, Highscore: 75 |                    ▕           ░░░░█░░░░          ▏
# EPISODE  85300 | Mean: 37.0, Highscore: 75 |  ▕                             ░░░░░░█░░░░                 ▏
# EPISODE  85400 | Mean: 34.5, Highscore: 75 |    ▕                         ░░░░░░█░░░               ▏
# EPISODE  85500 | Mean: 36.5, Highscore: 75 |           ▕                   ░░░░░░░█░░░                 ▏
# EPISODE  85600 | Mean: 36.1, Highscore: 75 |             ▕                   ░░░░█░░░           ▏
# EPISODE  85700 | Mean: 36.7, Highscore: 75 |             ▕                    ░░░█░░░                    ▏
# EPISODE  85800 | Mean: 36.3, Highscore: 75 |    ▕                           ░░░░░█░░░░              ▏
# EPISODE  85900 | Mean: 36.9, Highscore: 75 |                      ▕         ░░░░░█░░░░░         ▏
# EPISODE  86000 | Mean: 36.3, Highscore: 75 |                 ▕               ░░░█░░░░░         ▏
# EPISODE  86100 | Mean: 36.9, Highscore: 75 |              ▕                  ░░░░█░░░                        ▏
# EPISODE  86200 | Mean: 35.5, Highscore: 75 |               ▕               ░░░░░█░░░░░            ▏
# EPISODE  86300 | Mean: 38.0, Highscore: 75 |                       ▕           ░░░░█░░░░           ▏
# EPISODE  86400 | Mean: 37.1, Highscore: 75 |          ▕                       ░░░█░░░              ▏
# EPISODE  86500 | Mean: 35.7, Highscore: 75 |        ▕                       ░░░░█░░░░░             ▏
# EPISODE  86600 | Mean: 37.5, Highscore: 75 |                 ▕               ░░░░█░░░░                          ▏
# EPISODE  86700 | Mean: 38.3, Highscore: 75 |               ▕                  ░░░░█░░░░                  ▏
# EPISODE  86800 | Mean: 36.5, Highscore: 75 |                     ▕           ░░░█░░░░           ▏
# EPISODE  86900 | Mean: 35.8, Highscore: 75 |       ▕                       ░░░░░█░░░░░       ▏
# EPISODE  87000 | Mean: 37.4, Highscore: 75 |       ▕                          ░░█░░░░░                     ▏
# EPISODE  87100 | Mean: 38.6, Highscore: 75 |                      ▕            ░░░░░█░░             ▏
# EPISODE  87200 | Mean: 35.4, Highscore: 75 |         ▕                      ░░░░█░░░░             ▏
# EPISODE  87300 | Mean: 38.0, Highscore: 75 |       ▕                          ░░░░█░░░░              ▏
# EPISODE  87400 | Mean: 39.6, Highscore: 75 |                       ▕           ░░░░░█░░░░            ▏
# EPISODE  87500 | Mean: 37.9, Highscore: 75 |    ▕                             ░░░░█░░░░                   ▏
# EPISODE  87600 | Mean: 39.4, Highscore: 75 |                    ▕              ░░░░█░░░░░                 ▏
# EPISODE  87700 | Mean: 38.7, Highscore: 75 |                 ▕                 ░░░█░░░░              ▏
# EPISODE  87800 | Mean: 38.1, Highscore: 75 |            ▕                     ░░░░█░░░░              ▏
# EPISODE  87900 | Mean: 37.6, Highscore: 75 |                      ▕          ░░░░░█░░░                ▏
# EPISODE  88000 | Mean: 36.8, Highscore: 75 |                     ▕           ░░░░░█░░░               ▏
# EPISODE  88100 | Mean: 37.9, Highscore: 75 |         ▕                       ░░░░░█░░░░░                ▏
# EPISODE  88200 | Mean: 37.5, Highscore: 75 |                     ▕           ░░░░░█░░░              ▏
# EPISODE  88300 | Mean: 37.2, Highscore: 75 |          ▕                     ░░░░█░░░░░░                   ▏
# EPISODE  88400 | Mean: 37.7, Highscore: 75 |                       ▕         ░░░░░█░░░░                      ▏
# EPISODE  88500 | Mean: 36.4, Highscore: 75 |                    ▕           ░░░░█░░░░                 ▏
# EPISODE  88600 | Mean: 37.8, Highscore: 75 |                 ▕                ░░░░█░░░░░              ▏
# EPISODE  88700 | Mean: 37.2, Highscore: 75 |                       ▕         ░░░░█░░░░░               ▏
# EPISODE  88800 | Mean: 37.9, Highscore: 75 |                       ▕         ░░░░░█░░░░          ▏
# EPISODE  88900 | Mean: 37.8, Highscore: 75 |                     ▕            ░░░█░░░░░               ▏
# EPISODE  89000 | Mean: 36.8, Highscore: 75 |                       ▕        ░░░░░█░░░░░       ▏
# EPISODE  89100 | Mean: 37.4, Highscore: 75 |                       ▕         ░░░░█░░░░                ▏
# EPISODE  89200 | Mean: 36.9, Highscore: 75 |                     ▕          ░░░░░█░░░░          ▏
# EPISODE  89300 | Mean: 37.1, Highscore: 75 |                  ▕               ░░░░█░░                ▏
# EPISODE  89400 | Mean: 37.1, Highscore: 75 |         ▕                      ░░░░░█░░░░░░            ▏
# EPISODE  89500 | Mean: 36.8, Highscore: 75 |              ▕                 ░░░░░█░░░░                    ▏
# EPISODE  89600 | Mean: 36.0, Highscore: 75 | ▕                              ░░░░█░░░░░            ▏
# EPISODE  89700 | Mean: 38.5, Highscore: 75 |                    ▕            ░░░░░█░░░░░░                ▏
# EPISODE  89800 | Mean: 37.6, Highscore: 75 |                  ▕             ░░░░░█░░░░░                  ▏
# EPISODE  89900 | Mean: 36.1, Highscore: 75 |                    ▕           ░░░░█░░░░               ▏
# EPISODE  90000 | Mean: 38.9, Highscore: 75 |      ▕                           ░░░░█░░░░░                         ▏
# EPISODE  90100 | Mean: 36.0, Highscore: 75 |                 ▕             ░░░░░░█░░░              ▏
# EPISODE  90200 | Mean: 36.3, Highscore: 75 |          ▕                      ░░░█░░░░            ▏
# EPISODE  90300 | Mean: 36.4, Highscore: 75 |                   ▕             ░░░░█░░░           ▏
# EPISODE  90400 | Mean: 37.0, Highscore: 75 |                ▕               ░░░░░█░░░░                      ▏
# EPISODE  90500 | Mean: 38.2, Highscore: 75 |                       ▕          ░░░░░█░░░░                ▏
# EPISODE  90600 | Mean: 36.9, Highscore: 75 |                  ▕             ░░░░░█░░░░              ▏
# EPISODE  90700 | Mean: 37.7, Highscore: 75 |                     ▕           ░░░░█░░░░                ▏
# EPISODE  90800 | Mean: 37.1, Highscore: 75 |                       ▕        ░░░░█░░░░░                    ▏
# EPISODE  90900 | Mean: 35.4, Highscore: 75 | ▕                             ░░░░░█░░░░░     ▏
# EPISODE  91000 | Mean: 38.0, Highscore: 75 |                    ▕             ░░░░░█░░                      ▏
# EPISODE  91100 | Mean: 37.6, Highscore: 75 |  ▕                               ░░░░█░░░              ▏
# EPISODE  91200 | Mean: 37.0, Highscore: 75 |                      ▕           ░░█░░░░                  ▏
# EPISODE  91300 | Mean: 38.0, Highscore: 75 |                      ▕           ░░░░█░░░░            ▏
# EPISODE  91400 | Mean: 36.4, Highscore: 75 |                      ▕         ░░░░█░░░░              ▏
# EPISODE  91500 | Mean: 37.7, Highscore: 75 |                    ▕            ░░░░░█░░░░                 ▏
# EPISODE  91600 | Mean: 38.1, Highscore: 75 |                 ▕               ░░░░░█░░░░                        ▏
# EPISODE  91700 | Mean: 37.2, Highscore: 75 |                 ▕              ░░░░░░█░░░░               ▏
# EPISODE  91800 | Mean: 36.3, Highscore: 75 | ▕                              ░░░░░█░░░░░              ▏
# EPISODE  91900 | Mean: 38.1, Highscore: 75 |                 ▕                ░░░░█░░░░░              ▏
# EPISODE  92000 | Mean: 34.3, Highscore: 75 |                   ▕         ░░░░░░░█░░░              ▏
# EPISODE  92100 | Mean: 36.9, Highscore: 75 |                      ▕         ░░░░░█░░░░░░         ▏
# EPISODE  92200 | Mean: 36.8, Highscore: 75 |                       ▕         ░░░█░░░░░░             ▏
# EPISODE  92300 | Mean: 37.6, Highscore: 75 |                     ▕          ░░░░░░█░░░░             ▏
# EPISODE  92400 | Mean: 36.5, Highscore: 75 |                     ▕          ░░░░█░░░░░                 ▏
# EPISODE  92500 | Mean: 37.3, Highscore: 75 |             ▕                   ░░░░░█░░░            ▏
# EPISODE  92600 | Mean: 35.9, Highscore: 75 |                 ▕             ░░░░█░░░░                ▏
# EPISODE  92700 | Mean: 35.0, Highscore: 75 |              ▕             ░░░░░░░█░░░░░░         ▏
# EPISODE  92800 | Mean: 37.3, Highscore: 75 |               ▕                 ░░░░█░░░░░              ▏
# EPISODE  92900 | Mean: 37.2, Highscore: 75 |            ▕                     ░░░█░░░░                  ▏
# EPISODE  93000 | Mean: 32.6, Highscore: 75 |           ▕                 ░░░░░█░░░              ▏
# EPISODE  93100 | Mean: 35.1, Highscore: 75 |      ▕                         ░░░█░░░░░             ▏
# EPISODE  93200 | Mean: 34.7, Highscore: 75 |                  ▕             ░░░█░░░              ▏
# EPISODE  93300 | Mean: 34.3, Highscore: 75 |                    ▕         ░░░░█░░░░            ▏
# EPISODE  93400 | Mean: 35.3, Highscore: 75 |  ▕                            ░░░░░█░░░░                  ▏
# EPISODE  93500 | Mean: 36.5, Highscore: 75 |                 ▕            ░░░░░░█░░░░░░░         ▏
# EPISODE  93600 | Mean: 36.7, Highscore: 75 |    ▕                            ░░░░█░░░░░           ▏
# EPISODE  93700 | Mean: 38.1, Highscore: 75 |               ▕                ░░░░░░█░░░░░             ▏
# EPISODE  93800 | Mean: 38.2, Highscore: 75 |           ▕                      ░░░░█░░░░              ▏
# EPISODE  93900 | Mean: 36.7, Highscore: 75 |                ▕                ░░░░█░░░               ▏
# EPISODE  94000 | Mean: 37.0, Highscore: 75 |                   ▕            ░░░░░█░░░░                    ▏
# EPISODE  94100 | Mean: 36.2, Highscore: 75 |                 ▕              ░░░░█░░░░░               ▏
# EPISODE  94200 | Mean: 38.4, Highscore: 75 |                      ▕           ░░░░█░░░░░               ▏
# EPISODE  94300 | Mean: 37.2, Highscore: 75 |                    ▕             ░░░█░░░░              ▏
# EPISODE  94400 | Mean: 37.4, Highscore: 75 |                   ▕              ░░░█░░░░             ▏
# EPISODE  94500 | Mean: 37.1, Highscore: 75 |                     ▕          ░░░░░█░░░░░            ▏
# EPISODE  94600 | Mean: 35.9, Highscore: 75 |                ▕              ░░░░░░█░░░                 ▏
# EPISODE  94700 | Mean: 36.1, Highscore: 75 |                 ▕               ░░░░█░░              ▏
# EPISODE  94800 | Mean: 37.8, Highscore: 75 |                   ▕            ░░░░░█░░░░░░░               ▏
# EPISODE  94900 | Mean: 39.1, Highscore: 75 |               ▕                  ░░░░█░░░░░░                ▏
# EPISODE  95000 | Mean: 38.6, Highscore: 75 |                  ▕                ░░░░█░░░░                 ▏
# EPISODE  95100 | Mean: 35.6, Highscore: 75 |            ▕                   ░░░░█░░░░              ▏
# EPISODE  95200 | Mean: 37.0, Highscore: 75 |          ▕                    ░░░░░░█░░░░              ▏
# EPISODE  95300 | Mean: 37.4, Highscore: 75 |       ▕                           ░░░█░░░░             ▏
# EPISODE  95400 | Mean: 36.7, Highscore: 75 |            ▕                   ░░░░░█░░░░               ▏
# EPISODE  95500 | Mean: 39.1, Highscore: 75 |                ▕                 ░░░░█░░░░░░                     ▏
# EPISODE  95600 | Mean: 38.8, Highscore: 75 |           ▕                       ░░░█░░░░░                ▏
# EPISODE  95700 | Mean: 38.2, Highscore: 75 |                ▕                 ░░░░█░░░░               ▏
# EPISODE  95800 | Mean: 39.0, Highscore: 75 |                       ▕           ░░░█░░░░░░            ▏
# EPISODE  95900 | Mean: 37.3, Highscore: 75 |     ▕                           ░░░░░█░░░░░                ▏
# EPISODE  96000 | Mean: 36.6, Highscore: 75 |                    ▕            ░░░█░░░░           ▏
# EPISODE  96100 | Mean: 37.1, Highscore: 75 |           ▕                    ░░░░░█░░░░░                   ▏
# EPISODE  96200 | Mean: 36.4, Highscore: 75 |                   ▕           ░░░░░░█░░░░░            ▏
# EPISODE  96300 | Mean: 35.9, Highscore: 75 |           ▕                    ░░░░░█░░░              ▏
# EPISODE  96400 | Mean: 36.9, Highscore: 75 |            ▕                    ░░░░█░░░░               ▏
# EPISODE  96500 | Mean: 36.5, Highscore: 75 |        ▕                        ░░░░█░░░░             ▏
# EPISODE  96600 | Mean: 38.5, Highscore: 75 |                       ▕         ░░░░░█░░░░░                    ▏
# EPISODE  96700 | Mean: 38.3, Highscore: 75 |                 ▕               ░░░░█░░░░░               ▏
# EPISODE  96800 | Mean: 38.6, Highscore: 75 |                  ▕              ░░░░░█░░░░░░              ▏
# EPISODE  96900 | Mean: 38.4, Highscore: 75 |                       ▕          ░░░░█░░░                     ▏
# EPISODE  97000 | Mean: 36.6, Highscore: 75 |           ▕                   ░░░░░█░░░░░░░                   ▏
# EPISODE  97100 | Mean: 39.0, Highscore: 75 |                       ▕          ░░░░█░░░░░                 ▏
# EPISODE  97200 | Mean: 37.5, Highscore: 75 |                ▕                ░░░░░█░░░░               ▏
# EPISODE  97300 | Mean: 37.8, Highscore: 75 |                     ▕            ░░░█░░░░░░               ▏
# EPISODE  97400 | Mean: 36.5, Highscore: 75 |         ▕                      ░░░░░█░░░░              ▏
# EPISODE  97500 | Mean: 38.1, Highscore: 75 |           ▕                    ░░░░░░█░░░░░░                   ▏
# EPISODE  97600 | Mean: 36.5, Highscore: 75 |             ▕                 ░░░░░░█░░░░                    ▏
# EPISODE  97700 | Mean: 37.9, Highscore: 75 |                       ▕          ░░░░█░░░                   ▏
# EPISODE  97800 | Mean: 36.7, Highscore: 75 |             ▕                   ░░░█░░░░                    ▏
# EPISODE  97900 | Mean: 37.5, Highscore: 75 |                      ▕        ░░░░░░█░░░░░░                  ▏
# EPISODE  98000 | Mean: 39.2, Highscore: 75 |                 ▕                 ░░░░█░░░░░               ▏
# EPISODE  98100 | Mean: 37.1, Highscore: 75 |                   ▕            ░░░░█░░░░░                    ▏
# EPISODE  98200 | Mean: 37.2, Highscore: 75 |   ▕                             ░░░░░█░░░░            ▏
# EPISODE  98300 | Mean: 37.4, Highscore: 75 |                   ▕              ░░░█░░░░░            ▏
# EPISODE  98400 | Mean: 35.3, Highscore: 75 |               ▕                ░░░░░█░░░          ▏
# EPISODE  98500 | Mean: 37.9, Highscore: 75 |                       ▕         ░░░░█░░░░░                ▏
# EPISODE  98600 | Mean: 36.2, Highscore: 75 |                ▕               ░░░░█░░░░                 ▏
# EPISODE  98700 | Mean: 36.7, Highscore: 75 | ▕                               ░░░█░░░░░░░                ▏
# EPISODE  98800 | Mean: 37.6, Highscore: 75 |              ▕                   ░░░█░░░░░               ▏
# EPISODE  98900 | Mean: 37.5, Highscore: 75 |                     ▕          ░░░░░░█░░░░                 ▏
# EPISODE  99000 | Mean: 35.9, Highscore: 75 | ▕                             ░░░░░░█░░░░         ▏
# EPISODE  99100 | Mean: 36.3, Highscore: 75 |           ▕                    ░░░░░█░░░░         ▏
# EPISODE  99200 | Mean: 35.2, Highscore: 75 |           ▕                   ░░░░█░░░░               ▏
# EPISODE  99300 | Mean: 35.7, Highscore: 75 |  ▕                            ░░░░░░█░░░               ▏
# EPISODE  99400 | Mean: 36.8, Highscore: 75 |                  ▕             ░░░░░█░░░░░             ▏
# EPISODE  99500 | Mean: 38.9, Highscore: 75 |                     ▕             ░░░█░░░░░                   ▏
# EPISODE  99600 | Mean: 37.6, Highscore: 75 |                      ▕          ░░░░█░░░░                    ▏
# EPISODE  99700 | Mean: 37.3, Highscore: 75 |                 ▕                ░░░█░░░              ▏
# EPISODE  99800 | Mean: 39.8, Highscore: 75 |                       ▕           ░░░░█░░░░░░░            ▏
# EPISODE  99900 | Mean: 37.9, Highscore: 75 |             ▕                     ░░░█░░░░          ▏
# EPISODE 100000 | Mean: 37.1, Highscore: 75 |     ▕                          ░░░░░█░░░░░░                     ▏
# Training complete!

# %% [markdown]
# ### 5. Results
# After training for 100,000 episodes, we observe that the best agent developed a strategy that achieved a highscore of 75 on a 12x9 grid, reaching a total length of 79 segments. This corresponds to nearly 75% of the game area, despite the limited, snake-centric observation space.
# <center><img src="../assets/gameplay.gif"/></center>

# %%
from game.env import SnakeEnv
from agent import ACN

# Create a new game instance, this time with a GUI, and load the best model.
env = SnakeEnv(
    width      = 12,
    height     = 9,
    gui        = False,
    fps        = 3,
)
model = ACN(
    observation_space = env.observation_space,
    action_space      = env.action_space,
    hidden_size       = 128,
).load('../assets/models/preview/snake_agent_ppo_75.pth')

# Let the agent play the game.
best_game = env.evaluate(model, num_games = 150)
# Out:
# Mean: 36.84 | Highscore: 66

# %% [markdown]
# ### 6. References
# This project was inspired by the following video tutorials:
# - Patrick Loeber (2020). *[Teach AI to Play Snake](https://www.youtube.com/playlist?list=PLqnslRFeH2UrDh7vUmJ60YrmWd64mTTKV)*. Available on YouTube.
# - Edan Meyer (2021). *[Let’s Code Proximal Policy Optimization](https://www.youtube.com/watch?v=HR8kQMTO8bk)*. Available on YouTube.
